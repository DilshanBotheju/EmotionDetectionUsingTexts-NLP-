# %% [markdown]
# <a href="https://colab.research.google.com/github/DilshanBotheju/EmotionDetectionUsingTexts-NLP-/blob/ModelDevelopment/ModelTraining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Connect with google drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Load necessary libraris
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
file_path = "/content/drive/MyDrive/Emotion, Hate Speech and Violence Detection using NLP/datasets/combined_features.csv"
Emotion_data = pd.read_csv(file_path, encoding="latin-1")

# %%
print(Emotion_data.dtypes)
# Out:
# label             int64
# cleaned_text     object
# sentiment       float64
# dtype: object

# %%
Emotion_data.head()
# Out:
#    label                                       cleaned_text  sentiment
# 0      0  ive learned surround women lift leave feeling ...     0.1779
# 1      0    already feel crappy upset situation doesnt help    -0.8155
# 2      0  feel like lost mourned moved past tears relati...    -0.4588
# 3      0  could write whole lot im feeling crappy dont t...    -0.0516
# 4      0                        always seem feel inadequate    -0.4019
